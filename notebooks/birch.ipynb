# %%
import json
import pprint
from pathlib import Path
import sys
sys.path.insert(1, '../src/utils')
import ipdb
import itertools
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from gensim.utils import simple_preprocess
from gensim import corpora, models
from gensim.models import Word2Vec
from gensim.models import CoherenceModel
from sklearn.manifold import TSNE
from sklearn.cluster import SpectralClustering, Birch
from sklearn.mixture import GaussianMixture
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
from scipy.spatial.distance import cdist

from data import preprocessing
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Variables

# %%
num_topics = 15
use_title = True
# don't use stemming
stemming = False
lemmatization = True
# use nltk since it is a lot faster than spacy and the results are better with nltk
lib = "nltk"

input_path = Path("../src/data/data_jmlr_vol13-21.json")
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Data loading and preparation

# %% [markdown]
# ## load

# %%
def load_data():
    with open(input_path, encoding="utf-8") as f:
        data = json.load(f)
    data_df = pd.json_normalize(data['papers'])
    corpus = data_df["abstract"]
    if use_title:
        corpus = data_df["title"] + " " + corpus 
    return corpus
corpus = load_data()
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## preprocess
# TODO: save after preprocessing so that there is no need to wait for a long time

# %%
corpus = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15
)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# Dropping 0 entries of corpus, due to nan ...
# [nltk_data]   Package punkt is already up-to-date!
# 16it [00:00, 139.80it/s]
# Starting tokenization ...
# 1261it [00:06, 196.57it/s]

# %% [markdown]
# ### tfidf

# %%
def identity_tokenizer(text):
    return text

def get_tfidf_corpus(corpus):
    vectorizer = TfidfVectorizer(tokenizer=identity_tokenizer, lowercase=False)  
    return vectorizer, vectorizer.fit_transform(corpus["token"])
vectorizer, tfidf_corpus = get_tfidf_corpus(corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Clustering
# Start with default params and tied for the covariance type because of the high CPU and RAM usage with full.

# %%
def fit_model(model, corpus):
    model.fit(corpus)

def get_top_words(vectorizer, corpus):
    scores = zip(vectorizer.get_feature_names(),
                 np.asarray(corpus.sum(axis=0)).ravel())
    sorted_scores = list(zip(*sorted(scores, key=lambda x: x[1], reverse=True)))
    top_words = sorted_scores[0][:10]
    return top_words
    

def print_and_get_clusters(model, vectorizer, corpus, n_components=None, svd=None):
    print("Top terms per cluster:")
    clusters = []
    for i in range(np.max(model.labels_)+1):
        print("Cluster %d:" % i),
        vectorizer, tfidf_corpus = get_tfidf_corpus(corpus.iloc[np.where(model.labels_ == i)])
        top_words = get_top_words(vectorizer, tfidf_corpus)
        print(top_words)
        clusters.append(get_top_words(vectorizer, tfidf_corpus))
        print("\n")
    return clusters
    
model = Birch()
fit_model(model, tfidf_corpus.toarray())
clusters = print_and_get_clusters(model, vectorizer, corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('learning', 'algorithm', 'model', 'data', 'method', 'problem', 'function', 'kernel', 'regression', 'network')
#
#
# Cluster 1:
# ('model', 'algorithm', 'graph', 'matrix', 'data', 'method', 'clustering', 'learning', 'gaussian', 'problem')
#
#
# Cluster 2:
# ('causal', 'effect', 'data', 'variable', 'model', 'method', 'discovery', 'approach', 'algorithm', 'learning')

# %% [markdown]
# when using found subclusters there are only 3 clusters present.

# %% [markdown]
# # Visualization
#
# TODO: merge somehow with visualization of gensim_inspections? would be very difficult because of different inputs

# %%
def plot(model, corpus, n_components=None):
    random_state = 1
    #centroids = model.cluster_centers_

    tsne_init = 'pca'  # could also be 'random'
    tsne_perplexity = 20.0
    tsne_early_exaggeration = 4.0
    tsne_learning_rate = 10
    tsne = TSNE(n_components=2, random_state=random_state, init=tsne_init,
        perplexity=tsne_perplexity,
        early_exaggeration=tsne_early_exaggeration, learning_rate=tsne_learning_rate)
    if n_components:
        transformed = tsne.fit_transform(corpus)
    else:
        transformed = tsne.fit_transform(corpus.todense())
    plt.scatter(transformed[:, 0], transformed[:, 1], c=model.labels_, marker='x')
    plt.show()
plot(model, tfidf_corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# cluster looks good, but there are only very few clusters

# %% [markdown]
# # Remove words which appear often in all clusters

# %%
terms = list(itertools.chain.from_iterable(clusters))
Counter(terms).most_common
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <bound method Counter.most_common of Counter({'learning': 3, 'algorithm': 3, 'model': 3, 'data': 3, 'method': 3, 'problem': 2, 'function': 1, 'kernel': 1, 'regression': 1, 'network': 1, 'graph': 1, 'matrix': 1, 'clustering': 1, 'gaussian': 1, 'causal': 1, 'effect': 1, 'variable': 1, 'discovery': 1, 'approach': 1})>

# %% [markdown]
# most common words are similar to kmeans

# %%
custom_stopwords = ["algorithm", "data", "learning", "method", "model"]
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
corpus = load_data()

corpus_stopwords = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15,
    custom_stopwords = custom_stopwords
)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 41it [00:00, 197.78it/s]
# Dropping 0 entries of corpus, due to nan ...
# Starting tokenization ...
# 1261it [00:06, 200.83it/s]

# %%
vectorizer_stopwords, tfidf_corpus_stopwords = get_tfidf_corpus(corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model_stopwords = Birch()
fit_model(model_stopwords, tfidf_corpus_stopwords)
clusters_stopwords = print_and_get_clusters(model_stopwords, vectorizer_stopwords, corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('problem', 'matrix', 'kernel', 'function', 'network', 'based', 'graph', 'approach', 'set', 'regression')
#
#
# Cluster 1:
# ('causal', 'effect', 'variable', 'discovery', 'approach', 'cause', 'inference', 'instrumental', 'assumption', 'non')
#
#
# Cluster 2:
# ('stochastic', 'convex', 'distributed', 'optimization', 'problem', 'gradient', 'function', 'convergence', 'non', 'regression')

# %% [markdown]
# 3 clusters seem to be not enough?

# %%
terms = list(itertools.chain.from_iterable(clusters_stopwords))
Counter(terms).most_common
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <bound method Counter.most_common of Counter({'problem': 2, 'function': 2, 'approach': 2, 'regression': 2, 'non': 2, 'matrix': 1, 'kernel': 1, 'network': 1, 'based': 1, 'graph': 1, 'set': 1, 'causal': 1, 'effect': 1, 'variable': 1, 'discovery': 1, 'cause': 1, 'inference': 1, 'instrumental': 1, 'assumption': 1, 'stochastic': 1, 'convex': 1, 'distributed': 1, 'optimization': 1, 'gradient': 1, 'convergence': 1})>

# %% [markdown]
# Now there are other words, which could be removed

# %%
plot(model_stopwords, tfidf_corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# nice clusters visible

# %% [markdown]
# # Try with more clusters

# %%
model_more_clusters = Birch(n_clusters = num_topics)
fit_model(model_more_clusters, tfidf_corpus.toarray())
clusters_more_clusters = print_and_get_clusters(model_more_clusters, vectorizer, corpus)
plot(model_more_clusters, tfidf_corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('learning', 'algorithm', 'method', 'model', 'problem', 'data', 'function', 'regression', 'bound', 'optimization')
#
#
# Cluster 1:
# ('learning', 'data', 'model', 'algorithm', 'label', 'method', 'prediction', 'machine', 'task', 'set')
#
#
# Cluster 2:
# ('clustering', 'density', 'cluster', 'algorithm', 'graph', 'estimation', 'based', 'data', 'spectral', 'matrix')
#
#
# Cluster 3:
# ('model', 'algorithm', 'data', 'inference', 'method', 'gaussian', 'selection', 'time', 'variable', 'process')
#
#
# Cluster 4:
# ('model', 'graphical', 'graph', 'lasso', 'algorithm', 'data', 'covariance', 'network', 'method', 'matrix')
#
#
# Cluster 5:
# ('algorithm', 'convex', 'stochastic', 'gradient', 'problem', 'function', 'method', 'optimization', 'non', 'constraint')
#
#
# Cluster 6:
# ('graph', 'vertex', 'kernel', 'random', 'learning', 'algorithm', 'problem', 'alexey', 'bibliography', 'nomination')
#
#
# Cluster 7:
# ('kernel', 'distributed', 'rate', 'algorithm', 'learning', 'method', 'regression', 'data', 'bound', 'function')
#
#
# Cluster 8:
# ('network', 'model', 'community', 'neural', 'layer', 'image', 'data', 'distribution', 'machine', 'method')
#
#
# Cluster 9:
# ('kernel', 'learning', 'mean', 'estimator', 'data', 'distribution', 'approximation', 'probability', 'measure', 'class')
#
#
# Cluster 10:
# ('matrix', 'rank', 'low', 'completion', 'bound', 'norm', 'factorization', 'data', 'algorithm', 'problem')
#
#
# Cluster 11:
# ('causal', 'effect', 'data', 'variable', 'model', 'method', 'discovery', 'approach', 'algorithm', 'learning')
#
#
# Cluster 12:
# ('tensor', 'data', 'rank', 'model', 'problem', 'decomposition', 'analysis', 'estimation', 'regression', 'completion')
#
#
# Cluster 13:
# ('policy', 'learning', 'algorithm', 'iteration', 'method', 'gradient', 'search', 'problem', 'td', 'action')
#
#
# Cluster 14:
# ('subspace', 'problem', 'data', 'method', 'recovery', 'ms', 'learning', 'sample', 'sparse', 'robust')

# %%
model_stopwords_more_clusters = Birch(n_clusters = num_topics)
fit_model(model_stopwords_more_clusters, tfidf_corpus_stopwords)
clusters_stopwords = print_and_get_clusters(model_stopwords_more_clusters, vectorizer_stopwords, corpus_stopwords)
plot(model_stopwords_more_clusters, tfidf_corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('machine', 'feature', 'problem', 'set', 'classification', 'class', 'task', 'classifier', 'prediction', 'time')
#
#
# Cluster 1:
# ('graphical', 'lasso', 'selection', 'covariance', 'matrix', 'feature', 'sparse', 'change', 'high', 'gaussian')
#
#
# Cluster 2:
# ('problem', 'label', 'online', 'function', 'regret', 'bound', 'set', 'constraint', 'ranking', 'multi')
#
#
# Cluster 3:
# ('graph', 'dag', 'vertex', 'random', 'problem', 'time', 'markov', 'distribution', 'nomination', 'node')
#
#
# Cluster 4:
# ('network', 'community', 'neural', 'layer', 'node', 'structure', 'cascade', 'detection', 'distribution', 'estimation')
#
#
# Cluster 5:
# ('stochastic', 'convex', 'distributed', 'optimization', 'problem', 'gradient', 'function', 'convergence', 'non', 'regression')
#
#
# Cluster 6:
# ('inference', 'process', 'time', 'variational', 'latent', 'bayesian', 'gaussian', 'distribution', 'variable', 'approach')
#
#
# Cluster 7:
# ('kernel', 'mean', 'approximation', 'performance', 'estimator', 'class', 'distribution', 'probability', 'measure', 'feature')
#
#
# Cluster 8:
# ('causal', 'effect', 'variable', 'discovery', 'approach', 'cause', 'inference', 'instrumental', 'assumption', 'non')
#
#
# Cluster 9:
# ('policy', 'iteration', 'gradient', 'search', 'action', 'based', 'problem', 'td', 'function', 'evaluation')
#
#
# Cluster 10:
# ('matrix', 'rank', 'bound', 'low', 'completion', 'approximation', 'sampling', 'norm', 'error', 'problem')
#
#
# Cluster 11:
# ('clustering', 'density', 'cluster', 'graph', 'estimation', 'based', 'spectral', 'matrix', 'number', 'set')
#
#
# Cluster 12:
# ('tensor', 'rank', 'clustering', 'problem', 'decomposition', 'analysis', 'estimation', 'regression', 'completion', 'latent')
#
#
# Cluster 13:
# ('subspace', 'problem', 'recovery', 'sample', 'ms', 'sparse', 'robust', 'underlying', 'dimension', 'vector')
#
#
# Cluster 14:
# ('regression', 'problem', 'function', 'bound', 'loss', 'kernel', 'sample', 'rate', 'linear', 'matrix')

# %% [markdown]
# # LSA

# %%
def get_lsa_transformation(n_components, corpus):
    svd = TruncatedSVD(n_components)
    normalizer = Normalizer(copy=False)
    lsa = make_pipeline(svd, normalizer)
    return lsa.fit_transform(corpus),svd
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# use n_components=10 because it was used with kmeans. TODO: test with other vals for n_components.

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus)
num_topics = 15
model_lsa = Birch()
fit_model(model_lsa, X)
clusters_with_lsa = print_and_get_clusters(model_lsa, vectorizer, corpus, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('algorithm', 'method', 'matrix', 'kernel', 'problem', 'learning', 'data', 'regression', 'model', 'function')
#
#
# Cluster 1:
# ('graph', 'model', 'causal', 'graphical', 'algorithm', 'data', 'variable', 'learning', 'effect', 'method')
#
#
# Cluster 2:
# ('model', 'learning', 'data', 'network', 'algorithm', 'method', 'problem', 'feature', 'approach', 'policy')

# %% [markdown]
# Also with LSA we have only 3 clusters.

# %%
plot(model_lsa, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus_stopwords)
model_lsa_stopwords = Birch()
fit_model(model_lsa_stopwords, X)
clusters_with_lsa_stopwords = print_and_get_clusters(model_lsa_stopwords, vectorizer_stopwords, corpus_stopwords, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('problem', 'matrix', 'function', 'kernel', 'regression', 'graph', 'approach', 'bound', 'based', 'set')
#
#
# Cluster 1:
# ('alexey', 'bibliography', 'chervonenkis', 'comment', 'introductory')
#
#
# Cluster 2:
# ('network', 'machine', 'neural', 'library', 'python', 'time', 'framework', 'feature', 'set', 'multi')

# %%
plot(model_lsa_stopwords, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Third cluster only one document?

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus)
model_lsa_more_clusters = Birch(n_clusters=num_topics)
fit_model(model_lsa_more_clusters, X)
clusters_with_lsa_more_clusters = print_and_get_clusters(model_lsa_more_clusters, vectorizer, corpus, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('graph', 'model', 'graphical', 'algorithm', 'data', 'learning', 'problem', 'based', 'gaussian', 'method')
#
#
# Cluster 1:
# ('algorithm', 'method', 'problem', 'optimization', 'stochastic', 'function', 'gradient', 'convex', 'convergence', 'learning')
#
#
# Cluster 2:
# ('learning', 'label', 'algorithm', 'active', 'complexity', 'problem', 'setting', 'class', 'result', 'online')
#
#
# Cluster 3:
# ('network', 'model', 'neural', 'learning', 'algorithm', 'data', 'community', 'layer', 'method', 'node')
#
#
# Cluster 4:
# ('causal', 'variable', 'effect', 'data', 'model', 'method', 'algorithm', 'set', 'discovery', 'learning')
#
#
# Cluster 5:
# ('regression', 'model', 'estimator', 'method', 'data', 'high', 'dimensional', 'selection', 'lasso', 'estimation')
#
#
# Cluster 6:
# ('kernel', 'learning', 'data', 'regression', 'algorithm', 'function', 'method', 'based', 'rate', 'mean')
#
#
# Cluster 7:
# ('cluster', 'graph', 'clustering', 'axiom', 'quality', 'cut', 'result', 'function', 'edge', 'observed')
#
#
# Cluster 8:
# ('matrix', 'rank', 'method', 'low', 'data', 'algorithm', 'bound', 'completion', 'problem', 'norm')
#
#
# Cluster 9:
# ('learning', 'data', 'machine', 'algorithm', 'model', 'library', 'multi', 'python', 'feature', 'classification')
#
#
# Cluster 10:
# ('policy', 'learning', 'algorithm', 'model', 'method', 'problem', 'reinforcement', 'function', 'action', 'control')
#
#
# Cluster 11:
# ('model', 'inference', 'data', 'gaussian', 'process', 'method', 'variational', 'bayesian', 'latent', 'approach')
#
#
# Cluster 12:
# ('clustering', 'algorithm', 'density', 'cluster', 'data', 'based', 'estimation', 'spectral', 'hierarchical', 'model')
#
#
# Cluster 13:
# ('loss', 'bound', 'learning', 'rate', 'algorithm', 'sample', 'distribution', 'problem', 'class', 'regret')
#
#
# Cluster 14:
# ('data', 'feature', 'model', 'algorithm', 'learning', 'method', 'set', 'problem', 'class', 'classifier')

# %%
plot(model_lsa_more_clusters, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus_stopwords)
model_lsa_stopwords_more_clusters = Birch(n_clusters=num_topics)
fit_model(model_lsa_stopwords_more_clusters, X)
clusters_with_lsa__stopwords_more_clusters = print_and_get_clusters(model_lsa_stopwords_more_clusters, vectorizer_stopwords, corpus_stopwords, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
# ('feature', 'set', 'problem', 'class', 'classification', 'machine', 'approach', 'classifier', 'time', 'task')
#
#
# Cluster 1:
# ('policy', 'problem', 'reinforcement', 'agent', 'function', 'action', 'based', 'value', 'space', 'regret')
#
#
# Cluster 2:
# ('regression', 'lasso', 'high', 'selection', 'dimensional', 'estimator', 'sparse', 'variable', 'problem', 'linear')
#
#
# Cluster 3:
# ('alexey', 'bibliography', 'chervonenkis', 'comment', 'introductory')
#
#
# Cluster 4:
# ('inference', 'gaussian', 'process', 'variational', 'bayesian', 'approach', 'latent', 'approximation', 'prior', 'distribution')
#
#
# Cluster 5:
# ('kernel', 'regression', 'function', 'based', 'problem', 'mean', 'distributed', 'distribution', 'rate', 'space')
#
#
# Cluster 6:
# ('graph', 'graphical', 'problem', 'vertex', 'based', 'distribution', 'network', 'random', 'gaussian', 'set')
#
#
# Cluster 7:
# ('network', 'neural', 'community', 'layer', 'node', 'deep', 'set', 'structure', 'prediction', 'time')
#
#
# Cluster 8:
# ('matrix', 'rank', 'low', 'bound', 'problem', 'tensor', 'completion', 'norm', 'covariance', 'sampling')
#
#
# Cluster 9:
# ('stochastic', 'problem', 'optimization', 'gradient', 'convex', 'function', 'convergence', 'non', 'distributed', 'descent')
#
#
# Cluster 10:
# ('clustering', 'density', 'cluster', 'based', 'graph', 'spectral', 'hierarchical', 'problem', 'number', 'function')
#
#
# Cluster 11:
# ('bound', 'loss', 'sample', 'complexity', 'distribution', 'label', 'class', 'problem', 'setting', 'result')
#
#
# Cluster 12:
# ('causal', 'variable', 'effect', 'latent', 'approach', 'set', 'inference', 'discovery', 'graphical', 'condition')
#
#
# Cluster 13:
# ('machine', 'library', 'python', 'package', 'toolbox', 'source', 'multi', 'framework', 'classification', 'time')
#
#
# Cluster 14:
# ('regression', 'rate', 'estimator', 'function', 'convergence', 'bound', 'error', 'optimal', 'asymptotic', 'linear')

# %%
plot(model_lsa_stopwords_more_clusters, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Metrics
# Metrics provided from sklearn, that don't need true labels:
#
#     metrics.silhouette_score
#     metrics.calinski_harabasz_score
#     metrics.davies_bouldin_score
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics
#
# a higher Silhouette Coefficient score relates to a model with better defined clusters.
# he higher the calinski-harabasz score, the better the performances.
# A lower Davies-Bouldin index relates to a model with better separation between the clusters.
#
# https://medium.com/@haataa/how-to-measure-clustering-performances-when-there-are-no-ground-truth-db027e9a871c

# %%
def calc_scores(corpus, model):
    return metrics.silhouette_score(corpus, model.labels_, metric='euclidean'), metrics.calinski_harabasz_score(corpus.toarray(), model.labels_), metrics.davies_bouldin_score(corpus.toarray(), model.labels_)
scores = []
score = list(calc_scores(tfidf_corpus, model))
score.insert(0, 'normal model')
scores.append(score)
score = list(calc_scores(tfidf_corpus_stopwords, model_stopwords))
score.insert(0, 'model with custom stopwords')
scores.append(score)
score = list(calc_scores(tfidf_corpus, model_more_clusters))
score.insert(0, 'more clusters')
scores.append(score)
score = list(calc_scores(tfidf_corpus_stopwords, model_stopwords_more_clusters))
score.insert(0, 'more clusters with custom stopwords')
scores.append(score)
score = list(calc_scores(tfidf_corpus, model_lsa))
score.insert(0, 'model_lsa')
scores.append(score)
score = list(calc_scores(tfidf_corpus_stopwords, model_lsa_stopwords))
score.insert(0, 'model_lsa_stopwords')
scores.append(score)
score = list(calc_scores(tfidf_corpus, model_lsa_more_clusters))
score.insert(0, 'model_lsa_more_clusters')
scores.append(score)
score = list(calc_scores(tfidf_corpus_stopwords, model_lsa_stopwords_more_clusters))
score.insert(0, 'model_lsa_stopwords_more_clusters')
scores.append(score)


scores = pd.DataFrame(scores, columns=["model type","silhouette_score", "calinski_harabasz_score", "davies_bouldin_score"])
print(scores)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                             model type  silhouette_score  \
# 0                         normal model          0.002453
# 1          model with custom stopwords          0.000683
# 2                        more clusters          0.001654
# 3  more clusters with custom stopwords          0.003581
# 4                            model_lsa          0.004671
# 5                  model_lsa_stopwords          0.006807
# 6              model_lsa_more_clusters          0.010027
# 7    model_lsa_stopwords_more_clusters          0.012043
#
#    calinski_harabasz_score  davies_bouldin_score
# 0                 5.196730             10.386716
# 1                 5.120431              6.641520
# 2                 4.056009              6.833885
# 3                 4.157985              6.990993
# 4                 6.429278             11.281170
# 5                 3.666656              8.081296
# 6                 4.634880              7.164427
# 7                 4.569244              7.188701

# %% [markdown]
# with the silouette score and the davies-bouldin score it seems like the results are getting better with more clusters. With the other one it seems opposite.
# LSA seems to make it better. More clusters look better in the plot and wih the silhouette score. But it seems worse looking at calinski_harabasz_score
