# %%
import json
import pprint
from pathlib import Path
import sys
sys.path.insert(1, '../src/utils')
import ipdb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from gensim.utils import simple_preprocess
from gensim import corpora, models
from gensim.models import Word2Vec
from gensim.models import CoherenceModel
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
from scipy.spatial.distance import cdist

from data import preprocessing
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Variables

# %%
num_topics = 5
use_title = True
# don't use stemming
stemming = False
lemmatization = True
# use nltk since it is a lot faster than spacy and the results are better with nltk
lib = "nltk"

input_path = Path("../src/data/data_jmlr_vol13-21.json")
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # Data loading and preparation

# %% [markdown]
# ## load

# %%
with open(input_path, encoding="utf-8") as f:
    data = json.load(f)
data_df = pd.json_normalize(data['papers'])
corpus = data_df["abstract"]
if use_title:
    corpus = data_df["title"] + " " + corpus
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## preprocess
# TODO: save after preprocessing so that there is no need to wait for a long time

# %%
corpus = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15
)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0it [00:00, ?it/s]
# Dropping 0 entries of corpus, due to nan ...
# Starting tokenization ...
# 1261it [00:06, 185.27it/s]

# %% [markdown]
# ### tfidf

# %% [markdown]
# The TfidfVectorizer does additionally also tokenization and stop word removal.

# %%
vectorizer_sklearn = TfidfVectorizer(stop_words='english')
tfidf_corpus_sklearn_preprocessed = vectorizer_sklearn.fit_transform(corpus["abstract"])
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Since we implemented our own preprocessing this is not necessary. Therefore we don't use tokenization and lowercase. Since we didn't implement stop word removal yet(TODO: false -> remove stopword removal by sklearn) we use the stopword removal by sklearn.

# %%
def identity_tokenizer(text):
    return text

vectorizer = TfidfVectorizer(tokenizer=identity_tokenizer, lowercase=False)  
tfidf_corpus =  vectorizer.fit_transform(corpus["token"])
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## get optimal k

# %%
def find_k(corpus, num_topics):
    sum_of_suared_distances = []
    silhouette_scores = []
    K = range(2,num_topics)
    for k in K:
        model = KMeans(n_clusters=k, random_state=10)
        model.fit(corpus)
        sum_of_suared_distances.append(model.inertia_)
        labels = model.labels_
        silhouette_scores.append(metrics.silhouette_score(tfidf_corpus, labels, metric='euclidean'))

    # Plot the elbow
    plt.plot(K, sum_of_suared_distances, 'bx-')
    plt.xlabel('k')
    plt.ylabel('sum of squared distances')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

    # Plot silhouette scores
    plt.plot(K, silhouette_scores, 'bx-')
    plt.xlabel('k')
    plt.ylabel('silhouette score')
    plt.title('The silhouette score showing the optimal k')
    plt.show()
find_k(tfidf_corpus, 50)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
#  There is no elbow visible. There could be several reasons for this: https://stats.stackexchange.com/questions/89679/what-do-you-do-when-theres-no-elbow-point-for-kmeans-clustering

# %% [markdown]
# Silhouette score explained:
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
# TODO: proper visualization of silhouette score

# %% [markdown]
# Elbow Method explained: https://www.datanovia.com/en/lessons/determining-the-optimal-number-of-clusters-3-must-know-methods/

# %% [markdown]
# # Clustering

# %%
def fit_model(model, corpus):
    model.fit(corpus)

def print_and_get_clusters(model, vectorizer, n_components=None, svd=None):
    print("Top terms per cluster:")
    if n_components:
        original_space_centroids = svd.inverse_transform(model.cluster_centers_)
        order_centroids = original_space_centroids.argsort()[:, ::-1]
    else:
        order_centroids = model.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    clusters = []
    for i in range(num_topics):
        print("Cluster %d:" % i)
        cluster = []
        for ind in order_centroids[i, :10]:
            print(' %s' % terms[ind])
            cluster.append(terms[ind])
        clusters.append(cluster)
        print("\n")
    return clusters
    
model = KMeans(n_clusters=num_topics, init='k-means++', max_iter=100, n_init=1)
fit_model(model, tfidf_corpus)
clusters = print_and_get_clusters(model, vectorizer)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
#  label
#  learning
#  supervised
#  active
#  classification
#  algorithm
#  multi
#  data
#  problem
#  semi
#
#
# Cluster 1:
#  matrix
#  rank
#  completion
#  low
#  norm
#  bound
#  factorization
#  sampling
#  approximation
#  algorithm
#
#
# Cluster 2:
#  density
#  distribution
#  estimator
#  estimation
#  regression
#  bound
#  function
#  model
#  problem
#  rate
#
#
# Cluster 3:
#  gradient
#  stochastic
#  optimization
#  convex
#  algorithm
#  function
#  method
#  problem
#  convergence
#  descent
#
#
# Cluster 4:
#  policy
#  learning
#  action
#  reinforcement
#  control
#  decision
#  algorithm
#  process
#  td
#  iteration
#
#
# Cluster 5:
#  kernel
#  learning
#  function
#  space
#  hilbert
#  regression
#  norm
#  reproducing
#  regularization
#  data
#
#
# Cluster 6:
#  model
#  inference
#  data
#  variational
#  bayesian
#  method
#  process
#  gaussian
#  approach
#  feature
#
#
# Cluster 7:
#  algorithm
#  data
#  method
#  clustering
#  tensor
#  dictionary
#  sampling
#  problem
#  based
#  causal
#
#
# Cluster 8:
#  distributed
#  error
#  regression
#  rate
#  data
#  ridge
#  estimator
#  learning
#  bound
#  kernel
#
#
# Cluster 9:
#  learning
#  python
#  machine
#  library
#  task
#  source
#  package
#  toolbox
#  data
#  open
#
#
# Cluster 10:
#  covariance
#  lasso
#  subspace
#  matrix
#  model
#  sparse
#  group
#  dimensional
#  data
#  graphical
#
#
# Cluster 11:
#  graph
#  cluster
#  vertex
#  model
#  problem
#  edge
#  graphical
#  node
#  clustering
#  algorithm
#
#
# Cluster 12:
#  network
#  neural
#  model
#  causal
#  node
#  layer
#  structure
#  algorithm
#  learning
#  dag
#
#
# Cluster 13:
#  model
#  change
#  selection
#  point
#  graphical
#  data
#  variable
#  algorithm
#  criterion
#  detection
#
#
# Cluster 14:
#  loss
#  regret
#  online
#  multiclass
#  function
#  algorithm
#  margin
#  learning
#  risk
#  problem

# %% [markdown]
# Since the words which define the clusters look weird I use the sklearn preprocessing in the following. Our preprocessing should be improved. Or we decide to just use the sklearn preprocessing. But as far as I know they don't use lemmatization and stemming (TODO: true?)
# With no stemming, the use of nltk and lowering the words, the result seems to be better. Therfore we use our own preprocessing again.

# %%
model_skelarn_preprocessed = KMeans(n_clusters=num_topics, init='k-means++', max_iter=100, n_init=1)
fit_model(model_skelarn_preprocessed, tfidf_corpus_sklearn_preprocessed)
print_and_get_clusters(model_skelarn_preprocessed, vectorizer_sklearn)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
#  classification
#  class
#  classifiers
#  data
#  models
#  random
#  svm
#  high
#  sets
#  classes
#
#
# Cluster 1:
#  clustering
#  density
#  clusters
#  data
#  cluster
#  algorithm
#  persistence
#  estimation
#  hierarchical
#  graph
#
#
# Cluster 2:
#  graph
#  causal
#  graphical
#  models
#  latent
#  graphs
#  inference
#  data
#  variables
#  model
#
#
# Cluster 3:
#  community
#  detection
#  optimal
#  communities
#  block
#  networks
#  vertex
#  nomination
#  model
#  stochastic
#
#
# Cluster 4:
#  learning
#  model
#  networks
#  neural
#  network
#  deep
#  data
#  models
#  systems
#  search
#
#
# Cluster 5:
#  matrix
#  rank
#  low
#  completion
#  matrices
#  covariance
#  factorization
#  sparse
#  norm
#  model
#
#
# Cluster 6:
#  learning
#  feature
#  multi
#  task
#  data
#  gesture
#  features
#  algorithms
#  tasks
#  selection
#
#
# Cluster 7:
#  loss
#  learning
#  active
#  complexity
#  losses
#  bounds
#  regret
#  multiclass
#  sample
#  label
#
#
# Cluster 8:
#  kernel
#  online
#  learning
#  kernels
#  regression
#  function
#  data
#  hilbert
#  rkhs
#  algorithms
#
#
# Cluster 9:
#  bayesian
#  gaussian
#  cross
#  ep
#  validation
#  posterior
#  regression
#  priors
#  inference
#  model
#
#
# Cluster 10:
#  policy
#  variational
#  risk
#  markov
#  posterior
#  bayesian
#  algorithms
#  inference
#  approximation
#  monte
#
#
# Cluster 11:
#  sampling
#  pca
#  data
#  privacy
#  algorithms
#  subspace
#  problem
#  algorithm
#  bounds
#  method
#
#
# Cluster 12:
#  manifold
#  learning
#  supervised
#  data
#  semi
#  labels
#  algorithms
#  unlabeled
#  dimensional
#  labeled
#
#
# Cluster 13:
#  stochastic
#  gradient
#  optimization
#  convex
#  convergence
#  descent
#  algorithms
#  methods
#  algorithm
#  non
#
#
# Cluster 14:
#  regression
#  lasso
#  method
#  high
#  data
#  dimensional
#  estimation
#  sparse
#  selection
#  local
# [['classification',
#   'class',
#   'classifiers',
#   'data',
#   'models',
#   'random',
#   'svm',
#   'high',
#   'sets',
#   'classes'],
#  ['clustering',
#   'density',
#   'clusters',
#   'data',
#   'cluster',
#   'algorithm',
#   'persistence',
#   'estimation',
#   'hierarchical',
#   'graph'],
#  ['graph',
#   'causal',
#   'graphical',
#   'models',
#   'latent',
#   'graphs',
#   'inference',
#   'data',
#   'variables',
#   'model'],
#  ['community',
#   'detection',
#   'optimal',
#   'communities',
#   'block',
#   'networks',
#   'vertex',
#   'nomination',
#   'model',
#   'stochastic'],
#  ['learning',
#   'model',
#   'networks',
#   'neural',
#   'network',
#   'deep',
#   'data',
#   'models',
#   'systems',
#   'search'],
#  ['matrix',
#   'rank',
#   'low',
#   'completion',
#   'matrices',
#   'covariance',
#   'factorization',
#   'sparse',
#   'norm',
#   'model'],
#  ['learning',
#   'feature',
#   'multi',
#   'task',
#   'data',
#   'gesture',
#   'features',
#   'algorithms',
#   'tasks',
#   'selection'],
#  ['loss',
#   'learning',
#   'active',
#   'complexity',
#   'losses',
#   'bounds',
#   'regret',
#   'multiclass',
#   'sample',
#   'label'],
#  ['kernel',
#   'online',
#   'learning',
#   'kernels',
#   'regression',
#   'function',
#   'data',
#   'hilbert',
#   'rkhs',
#   'algorithms'],
#  ['bayesian',
#   'gaussian',
#   'cross',
#   'ep',
#   'validation',
#   'posterior',
#   'regression',
#   'priors',
#   'inference',
#   'model'],
#  ['policy',
#   'variational',
#   'risk',
#   'markov',
#   'posterior',
#   'bayesian',
#   'algorithms',
#   'inference',
#   'approximation',
#   'monte'],
#  ['sampling',
#   'pca',
#   'data',
#   'privacy',
#   'algorithms',
#   'subspace',
#   'problem',
#   'algorithm',
#   'bounds',
#   'method'],
#  ['manifold',
#   'learning',
#   'supervised',
#   'data',
#   'semi',
#   'labels',
#   'algorithms',
#   'unlabeled',
#   'dimensional',
#   'labeled'],
#  ['stochastic',
#   'gradient',
#   'optimization',
#   'convex',
#   'convergence',
#   'descent',
#   'algorithms',
#   'methods',
#   'algorithm',
#   'non'],
#  ['regression',
#   'lasso',
#   'method',
#   'high',
#   'data',
#   'dimensional',
#   'estimation',
#   'sparse',
#   'selection',
#   'local']]

# %% [markdown]
# lemmatization would be good, because the defining words are redundant(e.g. models and model, graphs and graph, ...)

# %% [markdown]
# # Visualization
#
# TODO: merge somehow with visualization of gensim_inspections? would be very difficult because of different inputs

# %%
def plot(model, corpus, n_components=None):
    random_state = 1
    centroids = model.cluster_centers_

    tsne_init = 'pca'  # could also be 'random'
    tsne_perplexity = 20.0
    tsne_early_exaggeration = 4.0
    tsne_learning_rate = 10
    tsne = TSNE(n_components=2, random_state=random_state, init=tsne_init,
        perplexity=tsne_perplexity,
        early_exaggeration=tsne_early_exaggeration, learning_rate=tsne_learning_rate)
    if n_components:
        transformed = tsne.fit_transform(np.concatenate((corpus, centroids)))
    else:
        transformed = tsne.fit_transform(np.concatenate((corpus.todense(), centroids)))
    plt.scatter(transformed[:-num_topics, 0], transformed[:-num_topics, 1], c=model.labels_, marker='x')
    plt.scatter(transformed[-num_topics:, 0], transformed[-num_topics:, 1], c="red", marker='o')

    plt.show()
plot(model, tfidf_corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # LSA and kmeans

# %%
def get_lsa_transformation(n_components, corpus):
    svd = TruncatedSVD(n_components)
    normalizer = Normalizer(copy=False)
    lsa = make_pipeline(svd, normalizer)
    return lsa.fit_transform(corpus),svd
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def find_n_components_and_k(corpus):
    for n_components in [2,3,4,5,6,7,8,9,10]:
        print("n_components: ", n_components)
        X, svd = get_lsa_transformation(n_components, corpus)
        find_k(X, 50)
find_n_components_and_k(tfidf_corpus)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# n_components:  2
# n_components:  3
# n_components:  4
# n_components:  5
# n_components:  6
# n_components:  7
# n_components:  8
# n_components:  9
# n_components:  10

# %% [markdown]
# With LSA and kmeans a elbow is visible! The peak of the silhouette score moves to the right the higher n_component.
# The optimal cluster number seems to be 15? With n_components = 9 also the peak of the silhouette score is at k=15. So maybe use num_topics= 15 and n_components=9?

# %%
n_components = 9
X, svd = get_lsa_transformation(n_components, tfidf_corpus)
num_topics = 15
model = KMeans(n_clusters=num_topics, init='k-means++', max_iter=100, n_init=1)
fit_model(model, X)
clusters_lsa = print_and_get_clusters(model, vectorizer, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
#  learning
#  data
#  machine
#  library
#  feature
#  task
#  python
#  classification
#  multi
#  label
#
#
# Cluster 1:
#  algorithm
#  matrix
#  clustering
#  method
#  data
#  problem
#  learning
#  graph
#  cluster
#  optimization
#
#
# Cluster 2:
#  model
#  causal
#  variable
#  data
#  graph
#  clustering
#  algorithm
#  inference
#  distribution
#  latent
#
#
# Cluster 3:
#  model
#  data
#  inference
#  variable
#  method
#  network
#  gaussian
#  latent
#  graphical
#  approach
#
#
# Cluster 4:
#  network
#  model
#  neural
#  graph
#  learning
#  graphical
#  node
#  deep
#  data
#  structure
#
#
# Cluster 5:
#  bound
#  learning
#  loss
#  class
#  rate
#  sample
#  estimator
#  distribution
#  optimal
#  problem
#
#
# Cluster 6:
#  kernel
#  regression
#  learning
#  function
#  estimator
#  density
#  rate
#  space
#  mean
#  approximation
#
#
# Cluster 7:
#  matrix
#  rank
#  low
#  completion
#  tensor
#  bound
#  norm
#  covariance
#  approximation
#  sparse
#
#
# Cluster 8:
#  algorithm
#  problem
#  learning
#  convex
#  function
#  bound
#  optimization
#  loss
#  method
#  rate
#
#
# Cluster 9:
#  policy
#  learning
#  algorithm
#  bound
#  regret
#  reinforcement
#  action
#  distribution
#  problem
#  online
#
#
# Cluster 10:
#  regression
#  model
#  estimator
#  method
#  data
#  rate
#  estimation
#  selection
#  high
#  dimensional
#
#
# Cluster 11:
#  model
#  inference
#  method
#  gaussian
#  bayesian
#  process
#  policy
#  data
#  variational
#  latent
#
#
# Cluster 12:
#  graph
#  clustering
#  algorithm
#  cluster
#  graphical
#  network
#  model
#  problem
#  data
#  node
#
#
# Cluster 13:
#  learning
#  data
#  model
#  algorithm
#  feature
#  label
#  classification
#  method
#  set
#  task
#
#
# Cluster 14:
#  algorithm
#  optimization
#  gradient
#  stochastic
#  convex
#  method
#  problem
#  function
#  convergence
#  descent

# %%
plot(model, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# cluster centers look better than without lsa.

# %% [markdown]
# # Remove words which appear often in all clusters

# %%
terms = list(itertools.chain.from_iterable(clusters))
Counter(terms).most_common
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <bound method Counter.most_common of Counter({'algorithm': 9, 'data': 8, 'learning': 7, 'problem': 6, 'model': 6, 'function': 4, 'bound': 3, 'regression': 3, 'method': 3, 'graphical': 3, 'matrix': 2, 'norm': 2, 'sampling': 2, 'estimator': 2, 'rate': 2, 'process': 2, 'kernel': 2, 'clustering': 2, 'causal': 2, 'node': 2, 'label': 1, 'supervised': 1, 'active': 1, 'classification': 1, 'multi': 1, 'semi': 1, 'rank': 1, 'completion': 1, 'low': 1, 'factorization': 1, 'approximation': 1, 'density': 1, 'distribution': 1, 'estimation': 1, 'gradient': 1, 'stochastic': 1, 'optimization': 1, 'convex': 1, 'convergence': 1, 'descent': 1, 'policy': 1, 'action': 1, 'reinforcement': 1, 'control': 1, 'decision': 1, 'td': 1, 'iteration': 1, 'space': 1, 'hilbert': 1, 'reproducing': 1, 'regularization': 1, 'inference': 1, 'variational': 1, 'bayesian': 1, 'gaussian': 1, 'approach': 1, 'feature': 1, 'tensor': 1, 'dictionary': 1, 'based': 1, 'distributed': 1, 'error': 1, 'ridge': 1, 'python': 1, 'machine': 1, 'library': 1, 'task': 1, 'source': 1, 'package': 1, 'toolbox': 1, 'open': 1, 'covariance': 1, 'lasso': 1, 'subspace': 1, 'sparse': 1, 'group': 1, 'dimensional': 1, 'graph': 1, 'cluster': 1, 'vertex': 1, 'edge': 1, 'network': 1, 'neural': 1, 'layer': 1, 'structure': 1, 'dag': 1, 'change': 1, 'selection': 1, 'point': 1, 'variable': 1, 'criterion': 1, 'detection': 1, 'loss': 1, 'regret': 1, 'online': 1, 'multiclass': 1, 'margin': 1, 'risk': 1})>

# %%
terms = list(itertools.chain.from_iterable(clusters_lsa))
Counter(terms).most_common
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <bound method Counter.most_common of Counter({'data': 9, 'learning': 8, 'algorithm': 7, 'method': 7, 'model': 7, 'problem': 6, 'graph': 4, 'bound': 4, 'rate': 4, 'clustering': 3, 'optimization': 3, 'inference': 3, 'distribution': 3, 'latent': 3, 'network': 3, 'graphical': 3, 'estimator': 3, 'function': 3, 'feature': 2, 'task': 2, 'classification': 2, 'label': 2, 'matrix': 2, 'cluster': 2, 'variable': 2, 'gaussian': 2, 'node': 2, 'loss': 2, 'regression': 2, 'approximation': 2, 'convex': 2, 'policy': 2, 'machine': 1, 'library': 1, 'python': 1, 'multi': 1, 'causal': 1, 'approach': 1, 'neural': 1, 'deep': 1, 'structure': 1, 'class': 1, 'sample': 1, 'optimal': 1, 'kernel': 1, 'density': 1, 'space': 1, 'mean': 1, 'rank': 1, 'low': 1, 'completion': 1, 'tensor': 1, 'norm': 1, 'covariance': 1, 'sparse': 1, 'regret': 1, 'reinforcement': 1, 'action': 1, 'online': 1, 'estimation': 1, 'selection': 1, 'high': 1, 'dimensional': 1, 'bayesian': 1, 'process': 1, 'variational': 1, 'set': 1, 'gradient': 1, 'stochastic': 1, 'convergence': 1, 'descent': 1})>

# %% [markdown]
# Words that should be removed are algorithm, data, learning, method, model. This insight corresponds to the insight we get by printing the topwords of BoW and tfidf corpuses (milestone)

# %%
custom_stopwords = ["algorithm", "data", "learning", "method", "model"]
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
corpus = load_data()

corpus_stopwords = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15,
    custom_stopwords = custom_stopwords
)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Jessi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 19it [00:00, 189.96it/s]
# Dropping 0 entries of corpus, due to nan ...
# Starting tokenization ...
# 1261it [00:06, 181.92it/s]

# %%
vectorizer_stopwords, tfidf_corpus_stopwords = get_tfidf_corpus(corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus_stopwords)
num_topics = 15
model_stopwords = KMeans(n_clusters=num_topics, init='k-means++', max_iter=100, n_init=1)
fit_model(model_stopwords, X)
clusters_with_lsa_stopwords = print_and_get_clusters(model_stopwords, vectorizer_stopwords, n_components=n_components, svd=svd)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top terms per cluster:
# Cluster 0:
#  gradient
#  optimization
#  stochastic
#  convex
#  function
#  problem
#  convergence
#  descent
#  distributed
#  objective
#
#
# Cluster 1:
#  problem
#  convex
#  bound
#  optimization
#  function
#  loss
#  rate
#  stochastic
#  gradient
#  convergence
#
#
# Cluster 2:
#  regression
#  lasso
#  estimator
#  sparse
#  selection
#  high
#  dimensional
#  feature
#  estimation
#  linear
#
#
# Cluster 3:
#  regression
#  estimator
#  lasso
#  dimensional
#  high
#  selection
#  estimation
#  matrix
#  sparse
#  variable
#
#
# Cluster 4:
#  network
#  neural
#  node
#  deep
#  structure
#  community
#  layer
#  training
#  graph
#  representation
#
#
# Cluster 5:
#  feature
#  inference
#  approach
#  bayesian
#  network
#  process
#  set
#  time
#  machine
#  task
#
#
# Cluster 6:
#  kernel
#  regression
#  function
#  estimator
#  rate
#  density
#  space
#  bound
#  mean
#  approximation
#
#
# Cluster 7:
#  graph
#  clustering
#  cluster
#  problem
#  graphical
#  spectral
#  based
#  density
#  kernel
#  node
#
#
# Cluster 8:
#  inference
#  causal
#  gaussian
#  variable
#  bayesian
#  process
#  latent
#  variational
#  distribution
#  approach
#
#
# Cluster 9:
#  policy
#  action
#  reinforcement
#  process
#  decision
#  problem
#  search
#  based
#  bound
#  function
#
#
# Cluster 10:
#  feature
#  classification
#  machine
#  library
#  label
#  multi
#  task
#  python
#  set
#  source
#
#
# Cluster 11:
#  matrix
#  rank
#  low
#  completion
#  bound
#  tensor
#  approximation
#  norm
#  problem
#  sampling
#
#
# Cluster 12:
#  feature
#  classification
#  label
#  problem
#  set
#  class
#  machine
#  multi
#  classifier
#  task
#
#
# Cluster 13:
#  bound
#  distribution
#  causal
#  sample
#  problem
#  class
#  rate
#  regret
#  loss
#  optimal
#
#
# Cluster 14:
#  graph
#  graphical
#  network
#  variable
#  causal
#  gaussian
#  estimator
#  estimation
#  inference
#  distribution

# %%
terms = list(itertools.chain.from_iterable(clusters_with_lsa_stopwords))
Counter(terms).most_common
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <bound method Counter.most_common of Counter({'problem': 7, 'bound': 5, 'function': 4, 'estimator': 4, 'feature': 4, 'rate': 3, 'regression': 3, 'estimation': 3, 'variable': 3, 'network': 3, 'graph': 3, 'inference': 3, 'process': 3, 'set': 3, 'machine': 3, 'task': 3, 'causal': 3, 'distribution': 3, 'gradient': 2, 'optimization': 2, 'stochastic': 2, 'convex': 2, 'convergence': 2, 'loss': 2, 'lasso': 2, 'sparse': 2, 'selection': 2, 'high': 2, 'dimensional': 2, 'matrix': 2, 'node': 2, 'approach': 2, 'bayesian': 2, 'kernel': 2, 'density': 2, 'approximation': 2, 'graphical': 2, 'based': 2, 'gaussian': 2, 'classification': 2, 'label': 2, 'multi': 2, 'class': 2, 'descent': 1, 'distributed': 1, 'objective': 1, 'linear': 1, 'neural': 1, 'deep': 1, 'structure': 1, 'community': 1, 'layer': 1, 'training': 1, 'representation': 1, 'time': 1, 'space': 1, 'mean': 1, 'clustering': 1, 'cluster': 1, 'spectral': 1, 'latent': 1, 'variational': 1, 'policy': 1, 'action': 1, 'reinforcement': 1, 'decision': 1, 'search': 1, 'library': 1, 'python': 1, 'source': 1, 'rank': 1, 'low': 1, 'completion': 1, 'tensor': 1, 'norm': 1, 'sampling': 1, 'classifier': 1, 'sample': 1, 'regret': 1, 'optimal': 1})>

# %%
plot(model_stopwords, X, n_components=n_components)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# The clusters look now not as good as before in my opinion. Maybe we need new k and n_components?

# %%
find_n_components_and_k(tfidf_corpus_stopwords)
# Out:
# c:\users\jessi\documents\studium\ws20_21\text analytics\ita_ws20\.venv\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-43b8b87554cb> in <module>
# ----> 1 find_n_components_and_k(tfidf_corpus_stopwords)
#
# NameError: name 'find_n_components_and_k' is not defined

# %% [markdown]
# Looks similar to before.
