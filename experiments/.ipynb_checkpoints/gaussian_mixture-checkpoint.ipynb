# %%
import json
import pprint
from pathlib import Path
import sys
sys.path.insert(1, '/src/utils')
## import ipdb
import itertools
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from gensim.utils import simple_preprocess
from gensim import corpora, models
from gensim.models import Word2Vec
from gensim.models import CoherenceModel
from sklearn.manifold import TSNE
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
#import pyLDAvis.gensim
#pyLDAvis.enable_notebook()
from scipy.spatial.distance import cdist

from data import preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6765c769234f> in <module>
#       9
#      10 import numpy as np
# ---> 11 import pandas as pd
#      12 import matplotlib.pyplot as plt
#      13
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Variables

# %%
num_topics = 15
use_title = True
# don't use stemming
stemming = False
lemmatization = True
# use nltk since it is a lot faster than spacy and the results are better with nltk
lib = "nltk"

input_path = Path("../src/data/data_jmlr_vol13-21.json")

# %% [markdown]
# # Data loading and preparation

# %% [markdown]
# ## load

# %%
def load_data():
    with open(input_path, encoding="utf-8") as f:
        data = json.load(f)
    data_df = pd.json_normalize(data['papers'])
    corpus = data_df["abstract"]
    if use_title:
        corpus = data_df["title"] + " " + corpus 
    return corpus
corpus = load_data()

# %% [markdown]
# ## preprocess
# TODO: save after preprocessing so that there is no need to wait for a long time

# %%
corpus = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15
)
# Out:
# 0it [00:00, ?it/s]
# Dropping 0 entries of corpus, due to nan ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Starting tokenization ...
# 1261it [00:04, 311.10it/s]

# %% [markdown]
# ### tfidf

# %%
def identity_tokenizer(text):
    return text

def get_tfidf_corpus(corpus):
    vectorizer = TfidfVectorizer(tokenizer=identity_tokenizer, lowercase=False)  
    return vectorizer, vectorizer.fit_transform(corpus["token"])
vectorizer, tfidf_corpus = get_tfidf_corpus(corpus)

# %% [markdown]
# # find optimal k
# TODO

# %% [markdown]
# # Clustering
# Start with default params and tied for the covariance type because of the high CPU and RAM usage with full.
# TODO: try different params

# %%
def fit_model(model, corpus):
    model.fit(corpus)

def get_top_words(vectorizer, corpus):
    scores = zip(vectorizer.get_feature_names(),
                 np.asarray(corpus.sum(axis=0)).ravel())
    sorted_scores = list(zip(*sorted(scores, key=lambda x: x[1], reverse=True)))
    top_words = sorted_scores[0][:10]
    return top_words
    

def print_and_get_clusters(model, vectorizer, corpus, labels, n_components=None, svd=None):
    print("Top terms per cluster:")
    clusters = []
    for i in range(num_topics):
        print("Cluster %d:" % i),
        vectorizer, tfidf_corpus = get_tfidf_corpus(corpus.iloc[np.where(labels == i)])
        top_words = get_top_words(vectorizer, tfidf_corpus)
        print(top_words)
        clusters.append(get_top_words(vectorizer, tfidf_corpus))
        print("\n")
    return clusters
    
model = GaussianMixture(n_components=num_topics, covariance_type="tied")
fit_model(model, tfidf_corpus.toarray())
labels = model.predict(tfidf_corpus.toarray())

clusters = print_and_get_clusters(model, vectorizer, corpus, labels)
# Out:
# Top terms per cluster:
# Cluster 0:
# ('learning', 'data', 'machine', 'library', 'python', 'algorithm', 'package', 'toolbox', 'source', 'model')
#
#
# Cluster 1:
# ('time', 'model', 'algorithm', 'data', 'markov', 'distribution', 'method', 'process', 'sampling', 'posterior')
#
#
# Cluster 2:
# ('task', 'estimator', 'learning', 'rate', 'estimation', 'bound', 'model', 'sample', 'data', 'distribution')
#
#
# Cluster 3:
# ('regression', 'method', 'distributed', 'data', 'high', 'model', 'dimensional', 'learning', 'algorithm', 'lasso')
#
#
# Cluster 4:
# ('kernel', 'learning', 'data', 'method', 'algorithm', 'function', 'density', 'model', 'based', 'problem')
#
#
# Cluster 5:
# ('algorithm', 'problem', 'method', 'convex', 'function', 'optimization', 'stochastic', 'gradient', 'learning', 'loss')
#
#
# Cluster 6:
# ('matrix', 'rank', 'low', 'method', 'completion', 'bound', 'data', 'algorithm', 'sampling', 'learning')
#
#
# Cluster 7:
# ('graph', 'clustering', 'algorithm', 'cluster', 'data', 'based', 'model', 'spectral', 'problem', 'random')
#
#
# Cluster 8:
# ('feature', 'data', 'gesture', 'model', 'selection', 'learning', 'method', 'set', 'recognition', 'algorithm')
#
#
# Cluster 9:
# ('causal', 'effect', 'variable', 'data', 'model', 'method', 'algorithm', 'learning', 'set', 'latent')
#
#
# Cluster 10:
# ('network', 'model', 'gaussian', 'inference', 'method', 'data', 'neural', 'learning', 'algorithm', 'process')
#
#
# Cluster 11:
# ('dictionary', 'learning', 'data', 'algorithm', 'norm', 'result', 'problem', 'sparse', 'linear', 'optimal')
#
#
# Cluster 12:
# ('model', 'learning', 'algorithm', 'data', 'problem', 'method', 'sample', 'approach', 'class', 'based')
#
#
# Cluster 13:
# ('policy', 'learning', 'algorithm', 'method', 'model', 'reinforcement', 'based', 'space', 'action', 'iteration')
#
#
# Cluster 14:
# ('classifier', 'forest', 'random', 'class', 'algorithm', 'loss', 'ensemble', 'learning', 'classification', 'boosting')

# %% [markdown]
# some words words are similar to kmeans. But there are a lot of words which are new. But the "buzzwords" are the same and the composition of words defining a cluster are very similar to kmeans.

# %% [markdown]
# # Visualization
#
# TODO: merge somehow with visualization of gensim_inspections? would be very difficult because of different inputs

# %%
def plot(model, corpus, labels, n_components=None):
    random_state = 1
    #centroids = model.cluster_centers_

    tsne_init = 'pca'  # could also be 'random'
    tsne_perplexity = 20.0
    tsne_early_exaggeration = 4.0
    tsne_learning_rate = 10
    tsne = TSNE(n_components=2, random_state=random_state, init=tsne_init,
        perplexity=tsne_perplexity,
        early_exaggeration=tsne_early_exaggeration, learning_rate=tsne_learning_rate)
    if n_components:
        transformed = tsne.fit_transform(corpus)
    else:
        transformed = tsne.fit_transform(corpus.todense())
    plt.scatter(transformed[:, 0], transformed[:, 1], c=labels, marker='x')
    plt.show()
plot(model, tfidf_corpus, labels)

# %% [markdown]
# no clusters visible

# %% [markdown]
# # Remove words which appear often in all clusters

# %%
terms = list(itertools.chain.from_iterable(clusters))
Counter(terms).most_common
# Out:
# <bound method Counter.most_common of Counter({'algorithm': 14, 'learning': 13, 'data': 12, 'model': 11, 'method': 10, 'problem': 5, 'based': 4, 'distribution': 2, 'process': 2, 'sampling': 2, 'bound': 2, 'sample': 2, 'function': 2, 'loss': 2, 'random': 2, 'set': 2, 'class': 2, 'machine': 1, 'library': 1, 'python': 1, 'package': 1, 'toolbox': 1, 'source': 1, 'time': 1, 'markov': 1, 'posterior': 1, 'task': 1, 'estimator': 1, 'rate': 1, 'estimation': 1, 'regression': 1, 'distributed': 1, 'high': 1, 'dimensional': 1, 'lasso': 1, 'kernel': 1, 'density': 1, 'convex': 1, 'optimization': 1, 'stochastic': 1, 'gradient': 1, 'matrix': 1, 'rank': 1, 'low': 1, 'completion': 1, 'graph': 1, 'clustering': 1, 'cluster': 1, 'spectral': 1, 'feature': 1, 'gesture': 1, 'selection': 1, 'recognition': 1, 'causal': 1, 'effect': 1, 'variable': 1, 'latent': 1, 'network': 1, 'gaussian': 1, 'inference': 1, 'neural': 1, 'dictionary': 1, 'norm': 1, 'result': 1, 'sparse': 1, 'linear': 1, 'optimal': 1, 'approach': 1, 'policy': 1, 'reinforcement': 1, 'space': 1, 'action': 1, 'iteration': 1, 'classifier': 1, 'forest': 1, 'ensemble': 1, 'classification': 1, 'boosting': 1})>

# %% [markdown]
# most common words are similar to kmeans

# %%
custom_stopwords = ["algorithm", "data", "learning", "method", "model"]

# %%
corpus = load_data()

corpus_stopwords = preprocessing(
    corpus,
    lib=lib,
    stemming=stemming,
    lemmatization=lemmatization,
    min_word_len=2,
    max_word_len=15,
    custom_stopwords = custom_stopwords
)
# Out:
# 50it [00:00, 489.98it/s]
# Dropping 0 entries of corpus, due to nan ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Starting tokenization ...
# 1261it [00:02, 525.34it/s]

# %%
vectorizer_stopwords, tfidf_corpus_stopwords = get_tfidf_corpus(corpus_stopwords)

# %%
model_stopwords = GaussianMixture(n_components=num_topics, covariance_type="tied")
fit_model(model_stopwords, tfidf_corpus_stopwords.toarray())
labels_stopwords = model_stopwords.predict(tfidf_corpus_stopwords.toarray())

clusters_stopwords = print_and_get_clusters(model_stopwords, vectorizer_stopwords, corpus_stopwords, labels_stopwords)
# Out:
# Top terms per cluster:
# Cluster 0:
# ('machine', 'python', 'library', 'package', 'toolbox', 'source', 'multi', 'classification', 'open', 'framework')
#
#
# Cluster 1:
# ('inference', 'process', 'variational', 'gaussian', 'bayesian', 'approach', 'approximation', 'latent', 'prior', 'posterior')
#
#
# Cluster 2:
# ('loss', 'function', 'problem', 'training', 'online', 'set', 'machine', 'classification', 'result', 'class')
#
#
# Cluster 3:
# ('bound', 'sample', 'estimator', 'regression', 'problem', 'rate', 'risk', 'optimal', 'class', 'distribution')
#
#
# Cluster 4:
# ('clustering', 'cluster', 'density', 'graph', 'based', 'spectral', 'number', 'matrix', 'set', 'problem')
#
#
# Cluster 5:
# ('kernel', 'regression', 'function', 'density', 'based', 'estimator', 'rate', 'mean', 'distributed', 'distribution')
#
#
# Cluster 6:
# ('causal', 'variable', 'effect', 'set', 'graph', 'latent', 'discovery', 'approach', 'inference', 'observational')
#
#
# Cluster 7:
# ('feature', 'lasso', 'selection', 'rule', 'variable', 'sparse', 'regression', 'problem', 'approach', 'high')
#
#
# Cluster 8:
# ('network', 'graph', 'graphical', 'neural', 'problem', 'high', 'set', 'dimensional', 'community', 'node')
#
#
# Cluster 9:
# ('stochastic', 'gradient', 'optimization', 'problem', 'convex', 'function', 'convergence', 'non', 'objective', 'rate')
#
#
# Cluster 10:
# ('prediction', 'local', 'regression', 'approach', 'gp', 'linear', 'dictionary', 'problem', 'ensemble', 'based')
#
#
# Cluster 11:
# ('policy', 'reinforcement', 'task', 'agent', 'problem', 'function', 'based', 'action', 'control', 'value')
#
#
# Cluster 12:
# ('tree', 'forest', 'random', 'time', 'graph', 'problem', 'classifier', 'decision', 'walk', 'using')
#
#
# Cluster 13:
# ('matrix', 'rank', 'low', 'bound', 'completion', 'norm', 'problem', 'sampling', 'sparse', 'covariance')
#
#
# Cluster 14:
# ('gesture', 'recognition', 'representation', 'hierarchical', 'feature', 'based', 'sign', 'image', 'human', 'classification')

# %%
terms = list(itertools.chain.from_iterable(clusters_stopwords))
Counter(terms).most_common
# Out:
# <bound method Counter.most_common of Counter({'problem': 10, 'based': 5, 'approach': 4, 'function': 4, 'set': 4, 'regression': 4, 'graph': 4, 'classification': 3, 'rate': 3, 'machine': 2, 'inference': 2, 'latent': 2, 'class': 2, 'bound': 2, 'estimator': 2, 'distribution': 2, 'density': 2, 'matrix': 2, 'variable': 2, 'feature': 2, 'sparse': 2, 'high': 2, 'python': 1, 'library': 1, 'package': 1, 'toolbox': 1, 'source': 1, 'multi': 1, 'open': 1, 'framework': 1, 'process': 1, 'variational': 1, 'gaussian': 1, 'bayesian': 1, 'approximation': 1, 'prior': 1, 'posterior': 1, 'loss': 1, 'training': 1, 'online': 1, 'result': 1, 'sample': 1, 'risk': 1, 'optimal': 1, 'clustering': 1, 'cluster': 1, 'spectral': 1, 'number': 1, 'kernel': 1, 'mean': 1, 'distributed': 1, 'causal': 1, 'effect': 1, 'discovery': 1, 'observational': 1, 'lasso': 1, 'selection': 1, 'rule': 1, 'network': 1, 'graphical': 1, 'neural': 1, 'dimensional': 1, 'community': 1, 'node': 1, 'stochastic': 1, 'gradient': 1, 'optimization': 1, 'convex': 1, 'convergence': 1, 'non': 1, 'objective': 1, 'prediction': 1, 'local': 1, 'gp': 1, 'linear': 1, 'dictionary': 1, 'ensemble': 1, 'policy': 1, 'reinforcement': 1, 'task': 1, 'agent': 1, 'action': 1, 'control': 1, 'value': 1, 'tree': 1, 'forest': 1, 'random': 1, 'time': 1, 'classifier': 1, 'decision': 1, 'walk': 1, 'using': 1, 'rank': 1, 'low': 1, 'completion': 1, 'norm': 1, 'sampling': 1, 'covariance': 1, 'gesture': 1, 'recognition': 1, 'representation': 1, 'hierarchical': 1, 'sign': 1, 'image': 1, 'human': 1})>

# %%
plot(model_stopwords, tfidf_corpus_stopwords, labels_stopwords)

# %% [markdown]
# Cluster looks a little bit better than before? But still not good.

# %% [markdown]
# # LSA

# %%
def get_lsa_transformation(n_components, corpus):
    svd = TruncatedSVD(n_components)
    normalizer = Normalizer(copy=False)
    lsa = make_pipeline(svd, normalizer)
    return lsa.fit_transform(corpus),svd

# %% [markdown]
# use n_components=10 because it was used with kmeans. TODO: test with other vals for n_components.

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus)
num_topics = 15
model_lsa = GaussianMixture(n_components=num_topics, covariance_type="tied")
fit_model(model_lsa, X)
labels = model_lsa.predict(X)
clusters_with_lsa = print_and_get_clusters(model_lsa, vectorizer, corpus, labels, n_components=n_components, svd=svd)

# %%
plot(model_lsa, X, labels, n_components=n_components)

# %%
n_components = 10
X, svd = get_lsa_transformation(n_components, tfidf_corpus_stopwords)
model_lsa_stopwords = GaussianMixture(n_components=num_topics, covariance_type="tied")
fit_model(model_lsa_stopwords, X)
labels = model_lsa_stopwords.predict(X)
clusters_with_lsa_stopwords = print_and_get_clusters(model_lsa_stopwords, vectorizer_stopwords, corpus_stopwords, labels, n_components=n_components, svd=svd)

# %%
plot(model_lsa_stopwords, X, labels, n_components=n_components)

# %% [markdown]
# # Metrics
# Metrics provided from sklearn, that don't need true labels:
#
#     metrics.silhouette_score
#     metrics.calinski_harabasz_score
#     metrics.davies_bouldin_score
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics

# %%
def calc_scores(corpus, model, labels):
    return metrics.silhouette_score(corpus, labels, metric='euclidean'), metrics.calinski_harabasz_score(corpus.toarray(), labels), metrics.davies_bouldin_score(corpus.toarray(), labels)
scores = []
score = list(calc_scores(tfidf_corpus, model, labels))
score.insert(0, 'normal model')
scores.append(score)
score = list(calc_scores(tfidf_corpus_stopwords, model_stopwords, labels_stopwords))
score.insert(0, 'model with custom stopwords')
scores.append(score)

scores = pd.DataFrame(scores, columns=["model type","silhouette_score", "calinski_harabasz_score", "davies_bouldin_score"])
print(scores)
# Out:
#                     model type  ...  davies_bouldin_score
# 0                 normal model  ...              7.584826
# 1  model with custom stopwords  ...              7.446258
#
# [2 rows x 4 columns]

# %% [markdown]
# kmeans achieves better scores.
